# %% [markdown]
# # AD-BoN runtime gateway
#
# This notebook executes the corrected, complete implementation in `final_phase_fixed.py`. The script runs the three diagnostic routes and assertion-based regression tests.

# %%
# %run ./final_phase_fixed.py
# Out:
# 2026-09-05 14:45:00,106 [INFO] [MOCK MODE] Using SemanticMockRouter — deterministic keyword-based classifier.
# 2026-09-05 14:45:00,282 [INFO] [MOCK MODE] Using SemanticMockRouter — deterministic keyword-based classifier.
# ...
# AD-BoN RUNTIME GATING GATEWAY REPORT
#   [ SYNTHETIC MOCK MODE — results are simulated ]
# ...
#
# User Query:
# What is the capital of France?
#
# Primary Semantic Cluster:
#   simple_factual (Cluster 0): 90.0%
#   Reason: Detected simple_factual terminology: "what is the capital", "capital of"
#
# Predicted Cluster Distribution  Phi(q):
#   [0] simple_factual          90.0%  ###################### <-- PRIMARY
#   [2] coding                  10.0%  ##
#
# Target Quality Threshold: 0.7600
#
# Model Configurations:
#   Model      N     E[Q]   Estimated Cost     Valid?
#   --------------------------------------------------
#   junior     1   0.6830 $    0.00010905    INVALID
#   junior     3   0.7939 $    0.00032505      VALID <-- SELECTED
# ...
